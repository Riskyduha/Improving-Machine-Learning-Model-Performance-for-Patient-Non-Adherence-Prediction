# %%
import pandas as pd
import numpy as np

# Preprocessing
from sklearn.model_selection import train_test_split, StratifiedKFold, cross_val_score
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.utils.class_weight import compute_class_weight

# Imbalanced data handling
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler

# Machine learning models
from xgboost import XGBClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier
from catboost import CatBoostClassifier
from lightgbm import LGBMClassifier
from sklearn.neural_network import MLPClassifier

# Evaluation
from sklearn.metrics import (
    precision_score,
    recall_score,
    balanced_accuracy_score,
    confusion_matrix,
    precision_recall_curve,
    auc
)

# Suppress warnings
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('data/medication_adherence.csv')

# %%
df.head()
# Out:
#   patient_id  age gender chronic_condition medication_type  dosage  \
# 0      P0103   45      M          diabetes       Metformin      50
# 1      P0436   79      M      hypertension       Metformin     500
# 2      P0861   71      F          diabetes      Salbutamol      20
# 3      P0271   89      M      hypertension    Atorvastatin      10
# 4      P0107   84      F          diabetes      Amlodipine      10
#
#    comorbidities    BMI event_id            timestamp  ...  blood_pressure  \
# 0              0 24.800   E00000  2025-05-22 02:46:32  ...          139/81
# 1              0 25.200   E00001  2025-03-02 22:26:25  ...          123/82
# 2              3 28.600   E00002  2025-09-13 02:37:54  ...          138/80
# 3              0 22.900   E00003  2025-01-26 03:54:55  ...          122/84
# 4              3 34.500   E00004  2025-02-20 03:28:37  ...          125/79
#
#   blood_glucose activity_level  sleep_hours stress_level  reminder_sent  \
# ...

# %%
df.tail()
# Out:
#      patient_id  age gender chronic_condition medication_type  dosage  \
# 2795      P0151   79      F    cardiovascular    Atorvastatin      50
# 2796      P0384   59      M          diabetes    Atorvastatin      50
# 2797      P0638   66      F            asthma       Metformin      50
# 2798      P0813   54      M      hypertension       Metformin     100
# 2799      P0308   77      F    cardiovascular      Salbutamol     100
#
#       comorbidities    BMI event_id            timestamp  ...  blood_pressure  \
# 2795              3 24.200   E02795  2025-01-07 05:26:36  ...          125/80
# 2796              1 24.700   E02796  2025-07-31 15:52:22  ...          122/77
# 2797              1 32.000   E02797  2025-02-12 08:02:04  ...          119/89
# 2798              2 19.400   E02798  2025-08-03 01:27:26  ...          127/70
# 2799              0 23.400   E02799  2025-03-22 20:24:04  ...          118/83
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2800 entries, 0 to 2799
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   patient_id              2800 non-null   object
#  1   age                     2800 non-null   int64
#  2   gender                  2800 non-null   object
#  3   chronic_condition       2800 non-null   object
#  4   medication_type         2800 non-null   object
#  5   dosage                  2800 non-null   int64
#  6   comorbidities           2800 non-null   int64
#  7   BMI                     2800 non-null   float64
#  8   event_id                2800 non-null   object
#  9   timestamp               2800 non-null   object
#  10  taken                   2800 non-null   int64
#  11  missed_reason           407 non-null    object
#  12  device_id               2800 non-null   object
#  13  heart_rate              2800 non-null   int64
# ...

# %%
df.describe()
# Out:
#            age   dosage  comorbidities      BMI    taken  heart_rate  \
# count 2800.000 2800.000       2800.000 2800.000 2800.000    2800.000
# mean    59.540  109.005          1.512   26.469    0.807      79.454
# std     17.216  169.817          1.126    4.885    0.394      11.456
# min     30.000    5.000          0.000   18.000    0.000      60.000
# 25%     45.000   10.000          1.000   22.300    1.000      70.000
# 50%     59.000   35.000          1.000   26.500    1.000      79.000
# 75%     74.000  100.000          3.000   30.625    1.000      90.000
# max     89.000  500.000          3.000   35.000    1.000      99.000
#
#        blood_glucose  activity_level  sleep_hours  stress_level  \
# count       2800.000        2800.000     2800.000      2800.000
# mean         125.762        5434.715        6.492         2.990
# std           31.714        2599.331        1.445         1.395
# min           70.000        1001.000        4.000         1.000
# ...

# %% [markdown]
# # Pre-processing

# %%
column_to_drop = [
    "patient_id",
    "event_id",
    "device_id",
    "timestamp"]

df = df.drop(columns=column_to_drop)
df.head()
# Out:
#    age gender chronic_condition medication_type  dosage  comorbidities    BMI  \
# 0   45      M          diabetes       Metformin      50              0 24.800
# 1   79      M      hypertension       Metformin     500              0 25.200
# 2   71      F          diabetes      Salbutamol      20              3 28.600
# 3   89      M      hypertension    Atorvastatin      10              0 22.900
# 4   84      F          diabetes      Amlodipine      10              3 34.500
#
#    taken  missed_reason  heart_rate blood_pressure  blood_glucose  \
# 0      1            NaN          70         139/81        170.200
# 1      0  forgetfulness          72         123/82         80.100
# 2      1            NaN          97         138/80        110.100
# 3      1            NaN          68         122/84        157.200
# 4      1            NaN          75         125/79        147.300
#
#    activity_level  sleep_hours  stress_level  reminder_sent  \
# ...

# %%
df = df.drop(['missed_reason', 'taken'], axis=1)

# %%
# Split blood_pressure
df[['systolic', 'diastolic']] = df['blood_pressure'].str.split('/', expand=True)

# Ubah ke integer
df['systolic'] = df['systolic'].astype(int)
df['diastolic'] = df['diastolic'].astype(int)

# Drop kolom lama
df = df.drop('blood_pressure', axis=1)

# %%
df.head()
# Out:
#    age gender chronic_condition medication_type  dosage  comorbidities    BMI  \
# 0   45      M          diabetes       Metformin      50              0 24.800
# 1   79      M      hypertension       Metformin     500              0 25.200
# 2   71      F          diabetes      Salbutamol      20              3 28.600
# 3   89      M      hypertension    Atorvastatin      10              0 22.900
# 4   84      F          diabetes      Amlodipine      10              3 34.500
#
#    heart_rate  blood_glucose  activity_level  sleep_hours  stress_level  \
# 0          70        170.200            8030        5.200             3
# 1          72         80.100            5338        8.800             2
# 2          97        110.100            9021        5.600             4
# 3          68        157.200            4930        4.800             4
# 4          75        147.300            5960        7.600             3
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2800 entries, 0 to 2799
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   age                     2800 non-null   int64
#  1   gender                  2800 non-null   object
#  2   chronic_condition       2800 non-null   object
#  3   medication_type         2800 non-null   object
#  4   dosage                  2800 non-null   int64
#  5   comorbidities           2800 non-null   int64
#  6   BMI                     2800 non-null   float64
#  7   heart_rate              2800 non-null   int64
#  8   blood_glucose           2800 non-null   float64
#  9   activity_level          2800 non-null   int64
#  10  sleep_hours             2800 non-null   float64
#  11  stress_level            2800 non-null   int64
#  12  reminder_sent           2800 non-null   int64
#  13  reminder_response_time  1966 non-null   float64
# ...

# %%
df.isnull().sum()
# Out:
# age                         0
# gender                      0
# chronic_condition           0
# medication_type             0
# dosage                      0
# comorbidities               0
# BMI                         0
# heart_rate                  0
# blood_glucose               0
# activity_level              0
# sleep_hours                 0
# stress_level                0
# reminder_sent               0
# reminder_response_time    834
# social_support              0
# location                    0
# future_non_adherence        0
# systolic                    0
# diastolic                   0
# dtype: int64

# %%
pd.crosstab(
    df['reminder_sent'],
    df['reminder_response_time'].isnull()
)
# Out:
# reminder_response_time  False  True
# reminder_sent
# 0                           0    834
# 1                        1966      0

# %%
df['reminder_response_time'] = df['reminder_response_time'].fillna(0)

# %%
df.isnull().sum()
# Out:
# age                       0
# gender                    0
# chronic_condition         0
# medication_type           0
# dosage                    0
# comorbidities             0
# BMI                       0
# heart_rate                0
# blood_glucose             0
# activity_level            0
# sleep_hours               0
# stress_level              0
# reminder_sent             0
# reminder_response_time    0
# social_support            0
# location                  0
# future_non_adherence      0
# systolic                  0
# diastolic                 0
# dtype: int64

# %%
X = df.drop('future_non_adherence', axis=1)
y = df['future_non_adherence']

# %%
y.value_counts()
# Out:
# future_non_adherence
# 0    2102
# 1     698
# Name: count, dtype: int64

# %%
X.select_dtypes(include='object').columns
# Out:
# Index(['gender', 'chronic_condition', 'medication_type', 'location'], dtype='object')

# %%
X['medication_type'].nunique()
# Out:
# 4

# %%
X['medication_type'].nunique()
# Out:
# 4

# %%
X_encoded = pd.get_dummies(
    X,
    columns=['gender', 'chronic_condition', 'medication_type', 'location'],
    drop_first=True
)

X_encoded.head()
# Out:
#    age  dosage  comorbidities    BMI  heart_rate  blood_glucose  \
# 0   45      50              0 24.800          70        170.200
# 1   79     500              0 25.200          72         80.100
# 2   71      20              3 28.600          97        110.100
# 3   89      10              0 22.900          68        157.200
# 4   84      10              3 34.500          75        147.300
#
#    activity_level  sleep_hours  stress_level  reminder_sent  ...  diastolic  \
# 0            8030        5.200             3              1  ...         81
# 1            5338        8.800             2              1  ...         82
# 2            9021        5.600             4              1  ...         80
# 3            4930        4.800             4              1  ...         84
# 4            5960        7.600             3              0  ...         79
#
#    gender_M  chronic_condition_cardiovascular  chronic_condition_diabetes  \
# ...

# %%
X_encoded.shape
# Out:
# (2800, 23)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_encoded,
    y,
    test_size=0.2,
    stratify=y,
    random_state=42
)

print("Train shape:", X_train.shape)
print("Test shape:", X_test.shape)

print("\nDistribusi train:")
print(y_train.value_counts(normalize=True))

print("\nDistribusi test:")
print(y_test.value_counts(normalize=True))
# Out:
# Train shape: (2240, 23)
# Test shape: (560, 23)
#
# Distribusi train:
# future_non_adherence
# 0   0.751
# 1   0.249
# Name: proportion, dtype: float64
#
# Distribusi test:
# future_non_adherence
# 0   0.750
# 1   0.250
# Name: proportion, dtype: float64

# %%
scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

X_train_scaled.shape, X_test_scaled.shape
# Out:
# ((2240, 23), (560, 23))

# %%
models = {
    "Random Forest": RandomForestClassifier(random_state=42),
    "Gradient Boosting": GradientBoostingClassifier(random_state=42),
    "AdaBoost": AdaBoostClassifier(random_state=42),
    "XGBoost": XGBClassifier(use_label_encoder=False, eval_metric='logloss', random_state=42),
    "CatBoost": CatBoostClassifier(verbose=0, random_state=42),
    "MLP": MLPClassifier(max_iter=500, random_state=42)
}

results = []

# %%
for name, model in models.items():
    
    # Untuk MLP gunakan scaled data
    if name == "MLP":
        model.fit(X_train_scaled, y_train)
        y_pred = model.predict(X_test_scaled)
        y_proba = model.predict_proba(X_test_scaled)[:, 1]
    else:
        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)
        y_proba = model.predict_proba(X_test)[:, 1]

    cm = confusion_matrix(y_test, y_pred)
    tn, fp, fn, tp = cm.ravel()

    precision = precision_score(y_test, y_pred, zero_division=0)
    recall = recall_score(y_test, y_pred)  # Sensitivity
    specificity = tn / (tn + fp) if (tn + fp) > 0 else 0
    balanced_acc = balanced_accuracy_score(y_test, y_pred)

    precision_curve, recall_curve, _ = precision_recall_curve(y_test, y_proba)
    pr_auc = auc(recall_curve, precision_curve)

    results.append([
        name,
        recall,
        precision,
        specificity,
        balanced_acc,
        pr_auc
    ])

# %%
results_df = pd.DataFrame(results, columns=[
    "Model",
    "Sensitivity (Recall)",
    "Precision",
    "Specificity",
    "Balanced Accuracy",
    "PR-AUC"
])

results_df
# Out:
#                Model  Sensitivity (Recall)  Precision  Specificity  \
# 0      Random Forest                 0.000      0.000        0.998
# 1  Gradient Boosting                 0.014      0.333        0.990
# 2           AdaBoost                 0.000      0.000        1.000
# 3            XGBoost                 0.071      0.244        0.926
# 4           CatBoost                 0.014      0.667        0.998
# 5                MLP                 0.179      0.245        0.817
#
#    Balanced Accuracy  PR-AUC
# 0              0.499   0.225
# 1              0.502   0.248
# 2              0.500   0.235
# 3              0.499   0.251
# 4              0.506   0.259
# 5              0.498   0.259

# %% [markdown]
# Random Forest & AdaBoost => Recall = 0 → model 100% mengabaikan kelas minoritas.
#
# Gradient Boosting & CatBoost => Recall sangat kecil → hanya sedikit instance minoritas yang terdeteksi.
#
# XGBoost => Mulai mendeteksi sebagian kecil, tapi masih sangat lemah.
#
# MLP => Recall tertinggi (0.178), tetapi specificity turun → trade-off mulai terlihat.

# %% [markdown]
# Hasil baseline menunjukkan bahwa seluruh model mengalami bias terhadap kelas mayoritas, ditunjukkan dengan nilai recall yang sangat rendah serta balanced accuracy mendekati 0.5. Hal ini mengindikasikan bahwa model belum mampu mempelajari pola kelas minoritas secara optimal akibat ketidakseimbangan distribusi data.

# %%
classes = np.unique(y_train)
class_weights = compute_class_weight(
    class_weight='balanced',
    classes=classes,
    y=y_train
)

class_weight_dict = dict(zip(classes, class_weights))

print("Class Weights:", class_weight_dict)
# Out:
# Class Weights: {np.int64(0): np.float64(0.6658739595719382), np.int64(1): np.float64(2.007168458781362)}

# %%
models_weighted = {
    "Random Forest": RandomForestClassifier(
        random_state=42,
        class_weight=class_weight_dict
    ),
    
    "Gradient Boosting": GradientBoostingClassifier(
        random_state=42
    ),
    
    "AdaBoost": AdaBoostClassifier(
        random_state=42
    ),
    
    "XGBoost": XGBClassifier(
        random_state=42,
        scale_pos_weight=class_weight_dict[1] / class_weight_dict[0],
        eval_metric='logloss',
        use_label_encoder=False
    ),
    
    "CatBoost": CatBoostClassifier(
        random_state=42,
        verbose=0,
        class_weights=[class_weight_dict[0], class_weight_dict[1]]
    ),
    
    "MLP": MLPClassifier(
        random_state=42,
        max_iter=500
    )
}

# %%
results_weighted = []

for name, model in models_weighted.items():
    
    # ==== TRAINING ====
    if name in ["Gradient Boosting", "AdaBoost"]:
        # gunakan sample_weight
        sample_weight = y_train.map(class_weight_dict)
        model.fit(X_train, y_train, sample_weight=sample_weight)
    else:
        model.fit(X_train, y_train)
    
    # ==== PREDICTION ====
    y_pred = model.predict(X_test)
    
    if hasattr(model, "predict_proba"):
        y_proba = model.predict_proba(X_test)[:, 1]
    else:
        y_proba = y_pred
    
    # ==== CONFUSION MATRIX ====
    cm = confusion_matrix(y_test, y_pred)
    tn, fp, fn, tp = cm.ravel()
    
    # ==== METRICS ====
    precision = precision_score(y_test, y_pred, zero_division=0)
    recall = recall_score(y_test, y_pred, zero_division=0)
    specificity = tn / (tn + fp) if (tn + fp) != 0 else 0
    balanced_acc = balanced_accuracy_score(y_test, y_pred)
    
    precision_curve, recall_curve, _ = precision_recall_curve(y_test, y_proba)
    pr_auc = auc(recall_curve, precision_curve)
    
    results_weighted.append([
        name,
        recall,
        precision,
        specificity,
        balanced_acc,
        pr_auc
    ])

# %%
results_weighted_df = pd.DataFrame(
    results_weighted,
    columns=[
        "Model",
        "Sensitivity (Recall)",
        "Precision",
        "Specificity",
        "Balanced Accuracy",
        "PR-AUC"
    ]
)

results_weighted_df
# Out:
#                Model  Sensitivity (Recall)  Precision  Specificity  \
# 0      Random Forest                 0.000      0.000        1.000
# 1  Gradient Boosting                 0.343      0.225        0.607
# 2           AdaBoost                 0.464      0.241        0.512
# 3            XGBoost                 0.179      0.240        0.812
# 4           CatBoost                 0.164      0.271        0.852
# 5                MLP                 0.000      0.000        1.000
#
#    Balanced Accuracy  PR-AUC
# 0              0.500   0.230
# 1              0.475   0.240
# 2              0.488   0.235
# 3              0.495   0.263
# 4              0.508   0.251
# 5              0.500   0.249

# %% [markdown]
# Penerapan cost-sensitive learning meningkatkan kemampuan model dalam mendeteksi kelas minoritas (future non-adherence), namun menyebabkan penurunan specificity serta belum memberikan peningkatan signifikan pada balanced accuracy dan PR-AUC.

# %% [markdown]
# Tujuan eksperimen ini:
#
# Menyeimbangkan data training dengan membuat sampel sintetis pada kelas minoritas.
#
# Meningkatkan sensitivity tanpa terlalu merusak specificity.
#
# Menguji apakah PR-AUC meningkat dibanding baseline dan class-weight.

# %%
from imblearn.over_sampling import SMOTE
from collections import Counter
# Inisialisasi SMOTE
smote = SMOTE(random_state=42)

# Terapkan hanya pada training data
X_train_sm, y_train_sm = smote.fit_resample(X_train, y_train)

# Cek distribusi setelah SMOTE
print("Distribusi sebelum SMOTE:", Counter(y_train))
print("Distribusi setelah SMOTE:", Counter(y_train_sm))
# Out:
# Distribusi sebelum SMOTE: Counter({0: 1682, 1: 558})
# Distribusi setelah SMOTE: Counter({0: 1682, 1: 1682})

# %%
results_smote = []

for name, model in models_weighted.items():
    
    # ==== TRAINING ====
    # Setelah SMOTE, data sudah seimbang -> sample_weight tidak diperlukan
    model.fit(X_train_sm, y_train_sm)
    
    # ==== PREDICTION ====
    y_pred = model.predict(X_test)
    
    if hasattr(model, "predict_proba"):
        y_proba = model.predict_proba(X_test)[:, 1]
    else:
        y_proba = y_pred
    
    # ==== CONFUSION MATRIX ====
    cm = confusion_matrix(y_test, y_pred)
    tn, fp, fn, tp = cm.ravel()
    
    # ==== METRICS ====
    precision = precision_score(y_test, y_pred, zero_division=0)
    recall = recall_score(y_test, y_pred, zero_division=0)
    specificity = tn / (tn + fp) if (tn + fp) != 0 else 0
    balanced_acc = balanced_accuracy_score(y_test, y_pred)
    
    precision_curve, recall_curve, _ = precision_recall_curve(y_test, y_proba)
    pr_auc = auc(recall_curve, precision_curve)
    
    results_smote.append([
        name,
        recall,
        precision,
        specificity,
        balanced_acc,
        pr_auc
    ])

# %%
# Ubah menjadi DataFrame supaya lebih rapi
results_smote_df = pd.DataFrame(
    results_smote,
    columns=["Model", "Sensitivity (Recall)", "Precision", "Specificity", "Balanced Accuracy", "PR-AUC"]
)

print(results_smote_df)
# Out:
#                Model  Sensitivity (Recall)  Precision  Specificity  \
# 0      Random Forest                 0.107      0.263        0.900
# 1  Gradient Boosting                 0.107      0.263        0.900
# 2           AdaBoost                 0.279      0.247        0.717
# 3            XGBoost                 0.250      0.276        0.781
# 4           CatBoost                 0.429      0.268        0.610
# 5                MLP                 0.057      0.222        0.933
#
#    Balanced Accuracy  PR-AUC
# 0              0.504   0.248
# 1              0.504   0.255
# 2              0.498   0.268
# 3              0.515   0.256
# 4              0.519   0.259
# 5              0.495   0.250

# %% [markdown]
# Analisis singkat:
#
# Sensitivity (Recall) meningkat terutama untuk CatBoost dan AdaBoost, menandakan SMOTE berhasil membantu model mengenali lebih banyak kasus minoritas.
#
# Precision sebagian besar sedikit menurun atau stabil dibandingkan cost-sensitive, karena oversampling minoritas sering menambah false positives.
#
# Specificity menurun untuk beberapa model (CatBoost, AdaBoost), tapi tetap cukup tinggi untuk Random Forest dan Gradient Boosting.
#
# Balanced Accuracy meningkat tipis untuk XGBoost dan CatBoost, menandakan distribusi prediksi lebih seimbang.
#
# PR-AUC ada peningkatan tipis pada beberapa model (AdaBoost, Gradient Boosting), menunjukkan kemampuan model menangkap kelas positif lebih baik secara keseluruhan.
#
# Kesimpulan sementara Cost-Sensitive Learning vs Smote:
#
# SMOTE lebih meningkatkan recall/sensitivity daripada cost-sensitive learning, tapi bisa menurunkan precision dan specificity sedikit.
#
# Jika fokusmu adalah mendeteksi kasus minoritas (misal pasien non-adherence), SMOTE memberikan improvement nyata pada recall.
#
# CatBoost dan AdaBoost terlihat paling diuntungkan oleh SMOTE dalam hal sensitivity.

# %%
from imblearn.under_sampling import RandomUnderSampler
from collections import Counter

# Inisialisasi RUS
rus = RandomUnderSampler(random_state=42)

# Terapkan hanya pada training data
X_train_rus, y_train_rus = rus.fit_resample(X_train, y_train)

# Cek distribusi setelah RUS
print("Distribusi sebelum RUS:", Counter(y_train))
print("Distribusi setelah RUS:", Counter(y_train_rus))
# Out:
# Distribusi sebelum RUS: Counter({0: 1682, 1: 558})
# Distribusi setelah RUS: Counter({0: 558, 1: 558})

# %%
results_rus = []

for name, model in models_weighted.items():
    
    # ==== TRAINING ====
    model.fit(X_train_rus, y_train_rus)
    
    # ==== PREDICTION ====
    y_pred = model.predict(X_test)
    
    if hasattr(model, "predict_proba"):
        y_proba = model.predict_proba(X_test)[:, 1]
    else:
        y_proba = y_pred
    
    # ==== CONFUSION MATRIX ====
    cm = confusion_matrix(y_test, y_pred)
    tn, fp, fn, tp = cm.ravel()
    
    # ==== METRICS ====
    precision = precision_score(y_test, y_pred, zero_division=0)
    recall = recall_score(y_test, y_pred, zero_division=0)
    specificity = tn / (tn + fp) if (tn + fp) != 0 else 0
    balanced_acc = balanced_accuracy_score(y_test, y_pred)
    
    precision_curve, recall_curve, _ = precision_recall_curve(y_test, y_proba)
    pr_auc = auc(recall_curve, precision_curve)
    
    results_rus.append([
        name,
        recall,
        precision,
        specificity,
        balanced_acc,
        pr_auc
    ])

# %%
# Buat DataFrame
results_rus_df = pd.DataFrame(
    results_rus,
    columns=["Model", "Sensitivity (Recall)", "Precision", "Specificity", "Balanced Accuracy", "PR-AUC"]
)

print(results_rus_df)
# Out:
#                Model  Sensitivity (Recall)  Precision  Specificity  \
# 0      Random Forest                 0.279      0.196        0.619
# 1  Gradient Boosting                 0.443      0.221        0.479
# 2           AdaBoost                 0.500      0.257        0.519
# 3            XGBoost                 0.514      0.205        0.333
# 4           CatBoost                 0.957      0.251        0.050
# 5                MLP                 0.979      0.262        0.083
#
#    Balanced Accuracy  PR-AUC
# 0              0.449   0.229
# 1              0.461   0.238
# 2              0.510   0.245
# 3              0.424   0.212
# 4              0.504   0.219
# 5              0.531   0.241

# %% [markdown]
# Analisis singkat RUS vs SMOTE vs Cost-Sensitive:
#
# Sensitivity (Recall) meningkat drastis untuk CatBoost dan MLP, hampir mendeteksi semua minoritas.
#
# Specificity turun drastis, terutama untuk CatBoost dan MLP → banyak mayoritas yang salah diklasifikasikan sebagai minoritas.
#
# Balanced Accuracy hanya sedikit lebih tinggi dibanding SMOTE untuk MLP, tapi overall cenderung menurun untuk model lain.
#
# Precision tetap rendah karena oversampling tidak dilakukan, sehingga banyak false positives.
#
# PR-AUC menurun untuk model dengan recall ekstrem tinggi → trade-off klasik RUS: mendeteksi minoritas tapi kehilangan performa klasifikasi mayoritas.
#
# Kesimpulan strategi RUS:
#
# Cocok kalau prioritas utama adalah recall untuk minoritas (misal pasien non-adherence, fraud detection).
#
# Tidak cocok jika precision atau keseluruhan balanced accuracy penting, karena mayoritas banyak yang salah klasifikasi.
#
# SMOTE biasanya lebih seimbang antara recall dan specificity dibanding RUS, sedangkan cost-sensitive learning lebih konservatif (specificity tinggi tapi recall rendah).

# %%
strategies = ["Cost-Sensitive", "SMOTE", "RUS"]

all_results = []

for df, strat in zip([results_weighted_df, results_smote_df, results_rus_df], strategies):
    for _, row in df.iterrows():
        all_results.append({
            "Model": row["Model"],
            "Strategy": strat,
            "Sensitivity (Recall)": row["Sensitivity (Recall)"],
            "Precision": row["Precision"],
            "Specificity": row["Specificity"],
            "Balanced Accuracy": row["Balanced Accuracy"],
            "PR-AUC": row["PR-AUC"]
        })

comparison_df = pd.DataFrame(all_results)

# Tampilkan tabel
pd.set_option('display.float_format', '{:.3f}'.format)
print(comparison_df.sort_values(["Model", "Strategy"]))
# Out:
#                 Model        Strategy  Sensitivity (Recall)  Precision  \
# 2            AdaBoost  Cost-Sensitive                 0.464      0.241
# 14           AdaBoost             RUS                 0.500      0.257
# 8            AdaBoost           SMOTE                 0.279      0.247
# 4            CatBoost  Cost-Sensitive                 0.164      0.271
# 16           CatBoost             RUS                 0.957      0.251
# 10           CatBoost           SMOTE                 0.429      0.268
# 1   Gradient Boosting  Cost-Sensitive                 0.343      0.225
# 13  Gradient Boosting             RUS                 0.443      0.221
# 7   Gradient Boosting           SMOTE                 0.107      0.263
# 5                 MLP  Cost-Sensitive                 0.000      0.000
# 17                MLP             RUS                 0.979      0.262
# 11                MLP           SMOTE                 0.057      0.222
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

metrics = ["Sensitivity (Recall)", "Precision", "Specificity", "Balanced Accuracy", "PR-AUC"]

# Membuat heatmap per metrik
plt.figure(figsize=(16, 10))

for i, metric in enumerate(metrics, 1):
    plt.subplot(2, 3, i)
    # Pivot table: index=Model, columns=Strategy, values=metric
    pivot = comparison_df.pivot(index="Model", columns="Strategy", values=metric)
    sns.heatmap(pivot, annot=True, fmt=".3f", cmap="YlGnBu", cbar=True)
    plt.title(metric)
    plt.ylabel("Model")
    plt.xlabel("Strategy")

plt.tight_layout()
plt.show()

# %% [markdown]
# Analisis:
#
# Cost-Sensitive: model tidak mendeteksi minoritas sama sekali.
#
# SMOTE: recall masih rendah, specificity tinggi → model sangat konservatif.
#
# RUS: recall hampir maksimal, specificity turun drastis → cocok jika minoritas prioritas, tapi banyak mayoritas salah klasifikasi.

# %% [markdown]
# # Summary
#
# Cost-Sensitive Learning: Recall rendah, specificity tinggi. Aman untuk mayoritas, kurang agresif untuk minoritas.
#
# SMOTE: Recall meningkat moderat, specificity masih cukup tinggi. Memberikan keseimbangan terbaik antara minoritas & mayoritas. PR-AUC biasanya tertinggi → kemampuan deteksi minoritas lebih stabil.
#
# RUS: Recall sangat tinggi (terutama CatBoost & MLP), specificity sangat rendah. Cocok jika fokus utama adalah mendeteksi minoritas, tapi precision turun karena banyak false positives.

# %% [markdown]
# # K-FOLD

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import recall_score, precision_score, balanced_accuracy_score, confusion_matrix, auc, precision_recall_curve
import numpy as np
import pandas as pd

# List untuk menyimpan hasil CV
cv_results = []

# Stratified K-Fold
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

for name, model in models_weighted.items():
    recalls, precisions, specs, bal_accs, pr_aucs = [], [], [], [], []

    for train_index, test_index in skf.split(X_train, y_train):
        X_tr, X_val = X_train.iloc[train_index], X_train.iloc[test_index]
        y_tr, y_val = y_train.iloc[train_index], y_train.iloc[test_index]

        # Fit model
        if name in ["Gradient Boosting", "AdaBoost"]:
            sample_weight = y_tr.map(class_weight_dict)
            model.fit(X_tr, y_tr, sample_weight=sample_weight)
        else:
            model.fit(X_tr, y_tr)

        # Prediksi
        y_pred = model.predict(X_val)
        y_proba = model.predict_proba(X_val)[:,1] if hasattr(model, "predict_proba") else y_pred

        # Confusion matrix
        tn, fp, fn, tp = confusion_matrix(y_val, y_pred).ravel()
        spec = tn / (tn + fp) if (tn + fp) != 0 else 0

        # Metrics
        recalls.append(recall_score(y_val, y_pred, zero_division=0))
        precisions.append(precision_score(y_val, y_pred, zero_division=0))
        specs.append(spec)
        bal_accs.append(balanced_accuracy_score(y_val, y_pred))

        precision_curve, recall_curve, _ = precision_recall_curve(y_val, y_proba)
        pr_aucs.append(auc(recall_curve, precision_curve))

    # Simpan rata-rata hasil tiap model
    cv_results.append({
        "Model": name,
        "Sensitivity (Recall)": np.mean(recalls),
        "Precision": np.mean(precisions),
        "Specificity": np.mean(specs),
        "Balanced Accuracy": np.mean(bal_accs),
        "PR-AUC": np.mean(pr_aucs)
    })

cv_results_df = pd.DataFrame(cv_results)
pd.set_option('display.float_format', '{:.3f}'.format)
print(cv_results_df)
# Out:
#                Model  Sensitivity (Recall)  Precision  Specificity  \
# 0      Random Forest                 0.002      0.067        0.998
# 1  Gradient Boosting                 0.342      0.238        0.638
# 2           AdaBoost                 0.454      0.244        0.533
# 3            XGBoost                 0.149      0.246        0.847
# 4           CatBoost                 0.169      0.261        0.841
# 5                MLP                 0.276      0.272        0.711
#
#    Balanced Accuracy  PR-AUC
# 0              0.500   0.264
# 1              0.490   0.251
# 2              0.493   0.248
# 3              0.498   0.257
# 4              0.505   0.264
# 5              0.493   0.252

# %% [markdown]
# # Cost-Sensitive Learning dengan Stratified K-Fold CV

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import recall_score, precision_score, balanced_accuracy_score, confusion_matrix, auc, precision_recall_curve
import pandas as pd
import numpy as np

# List untuk menyimpan hasil CV
cv_results = []

# Stratified K-Fold
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# Model yang mendukung Cost-Sensitive
cost_sensitive_models = ["Random Forest", "Gradient Boosting", "AdaBoost", "CatBoost"]

for name, model in models_weighted.items():
    recalls, precisions, specs, bal_accs, pr_aucs = [], [], [], [], []

    for train_index, test_index in skf.split(X_train, y_train):
        X_tr, X_val = X_train.iloc[train_index], X_train.iloc[test_index]
        y_tr, y_val = y_train.iloc[train_index], y_train.iloc[test_index]

        # Hitung sample_weight dari class_weight_dict
        if name in cost_sensitive_models:
            sample_weight = y_tr.map(class_weight_dict)
            model.fit(X_tr, y_tr, sample_weight=sample_weight)
        else:
            model.fit(X_tr, y_tr)  # fallback jika model tidak pakai sample_weight

        # Prediksi
        y_pred = model.predict(X_val)
        y_proba = model.predict_proba(X_val)[:,1] if hasattr(model, "predict_proba") else y_pred

        # Confusion matrix
        tn, fp, fn, tp = confusion_matrix(y_val, y_pred).ravel()
        spec = tn / (tn + fp) if (tn + fp) != 0 else 0

        # Metrics
        recalls.append(recall_score(y_val, y_pred, zero_division=0))
        precisions.append(precision_score(y_val, y_pred, zero_division=0))
        specs.append(spec)
        bal_accs.append(balanced_accuracy_score(y_val, y_pred))
        precision_curve, recall_curve, _ = precision_recall_curve(y_val, y_proba)
        pr_aucs.append(auc(recall_curve, precision_curve))

    # Simpan rata-rata hasil tiap model
    cv_results.append({
        "Model": name,
        "Sensitivity (Recall)": np.mean(recalls),
        "Precision": np.mean(precisions),
        "Specificity": np.mean(specs),
        "Balanced Accuracy": np.mean(bal_accs),
        "PR-AUC": np.mean(pr_aucs)
    })

cv_results_df = pd.DataFrame(cv_results)
pd.set_option('display.float_format', '{:.3f}'.format)
print(cv_results_df)
# Out:
#                Model  Sensitivity (Recall)  Precision  Specificity  \
# 0      Random Forest                 0.002      0.067        0.999
# 1  Gradient Boosting                 0.342      0.238        0.638
# 2           AdaBoost                 0.454      0.244        0.533
# 3            XGBoost                 0.149      0.246        0.847
# 4           CatBoost                 0.640      0.257        0.388
# 5                MLP                 0.276      0.272        0.711
#
#    Balanced Accuracy  PR-AUC
# 0              0.500   0.262
# 1              0.490   0.251
# 2              0.493   0.248
# 3              0.498   0.257
# 4              0.514   0.261
# 5              0.493   0.252

# %% [markdown]
# # SMOTE + Stratified CV

# %%
cv_results = []
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

for name, model in models_weighted.items():
    recalls, precisions, specs, bal_accs, pr_aucs = [], [], [], [], []

    for train_index, test_index in skf.split(X_train, y_train):
        X_tr, X_val = X_train.iloc[train_index], X_train.iloc[test_index]
        y_tr, y_val = y_train.iloc[train_index], y_train.iloc[test_index]

        # ==== Tentukan pipeline ====
        if name in ["Gradient Boosting", "AdaBoost"]:  # Cost-sensitive
            sample_weight = y_tr.map(class_weight_dict)
            model.fit(X_tr, y_tr, sample_weight=sample_weight)
            y_pred = model.predict(X_val)
            y_proba = model.predict_proba(X_val)[:,1] if hasattr(model, "predict_proba") else y_pred

        else:  # SMOTE + model untuk balance
            pipeline = Pipeline([
                ('smote', SMOTE(random_state=42)),
                ('clf', model)
            ])
            pipeline.fit(X_tr, y_tr)  # jangan beri sample_weight
            y_pred = pipeline.predict(X_val)
            y_proba = pipeline.predict_proba(X_val)[:,1] if hasattr(pipeline.named_steps['clf'], "predict_proba") else y_pred

        # Confusion matrix
        tn, fp, fn, tp = confusion_matrix(y_val, y_pred).ravel()
        spec = tn / (tn + fp) if (tn + fp) != 0 else 0

        # Metrics
        recalls.append(recall_score(y_val, y_pred, zero_division=0))
        precisions.append(precision_score(y_val, y_pred, zero_division=0))
        specs.append(spec)
        bal_accs.append(balanced_accuracy_score(y_val, y_pred))
        precision_curve, recall_curve, _ = precision_recall_curve(y_val, y_proba)
        pr_aucs.append(auc(recall_curve, precision_curve))

    cv_results.append({
        "Model": name,
        "Sensitivity (Recall)": np.mean(recalls),
        "Precision": np.mean(precisions),
        "Specificity": np.mean(specs),
        "Balanced Accuracy": np.mean(bal_accs),
        "PR-AUC": np.mean(pr_aucs)
    })

cv_results_df = pd.DataFrame(cv_results)
pd.set_option('display.float_format', '{:.3f}'.format)
print(cv_results_df)
# Out:
#                Model  Sensitivity (Recall)  Precision  Specificity  \
# 0      Random Forest                 0.077      0.245        0.922
# 1  Gradient Boosting                 0.342      0.238        0.638
# 2           AdaBoost                 0.454      0.244        0.533
# 3            XGBoost                 0.238      0.274        0.790
# 4           CatBoost                 0.387      0.255        0.625
# 5                MLP                 0.589      0.251        0.421
#
#    Balanced Accuracy  PR-AUC
# 0              0.499   0.256
# 1              0.490   0.251
# 2              0.493   0.248
# 3              0.514   0.265
# 4              0.506   0.263
# 5              0.505   0.256

# %% [markdown]
# # Random Under Sampling (RUS) dengan Stratified K-Fold CV.

# %%
from imblearn.under_sampling import RandomUnderSampler
from imblearn.pipeline import Pipeline
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import recall_score, precision_score, balanced_accuracy_score, confusion_matrix, auc, precision_recall_curve
import pandas as pd
import numpy as np

# List untuk menyimpan hasil CV
cv_results = []

# Stratified K-Fold
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

for name, model in models_weighted.items():
    recalls, precisions, specs, bal_accs, pr_aucs = [], [], [], [], []

    for train_index, test_index in skf.split(X_train, y_train):
        X_tr, X_val = X_train.iloc[train_index], X_train.iloc[test_index]
        y_tr, y_val = y_train.iloc[train_index], y_train.iloc[test_index]

        # Pipeline: RUS + Model
        pipeline = Pipeline([
            ('rus', RandomUnderSampler(random_state=42)),
            ('clf', model)
        ])

        # Fit model
        if name in ["Gradient Boosting", "AdaBoost"]:
            # untuk model boosting, tetap bisa gunakan sample_weight
            sample_weight = y_tr.map(class_weight_dict)
            pipeline.fit(X_tr, y_tr)  # RUS sudah menyeimbangkan, tidak perlu sample_weight
        else:
            pipeline.fit(X_tr, y_tr)

        # Prediksi
        y_pred = pipeline.predict(X_val)
        y_proba = pipeline.predict_proba(X_val)[:,1] if hasattr(pipeline.named_steps['clf'], "predict_proba") else y_pred

        # Confusion matrix
        tn, fp, fn, tp = confusion_matrix(y_val, y_pred).ravel()
        spec = tn / (tn + fp) if (tn + fp) != 0 else 0

        # Metrics
        recalls.append(recall_score(y_val, y_pred, zero_division=0))
        precisions.append(precision_score(y_val, y_pred, zero_division=0))
        specs.append(spec)
        bal_accs.append(balanced_accuracy_score(y_val, y_pred))
        precision_curve, recall_curve, _ = precision_recall_curve(y_val, y_proba)
        pr_aucs.append(auc(recall_curve, precision_curve))

    # Simpan rata-rata hasil tiap model
    cv_results.append({
        "Model": name,
        "Sensitivity (Recall)": np.mean(recalls),
        "Precision": np.mean(precisions),
        "Specificity": np.mean(specs),
        "Balanced Accuracy": np.mean(bal_accs),
        "PR-AUC": np.mean(pr_aucs)
    })

cv_results_df = pd.DataFrame(cv_results)
pd.set_option('display.float_format', '{:.3f}'.format)
print(cv_results_df)
# Out:
#                Model  Sensitivity (Recall)  Precision  Specificity  \
# 0      Random Forest                 0.348      0.239        0.634
# 1  Gradient Boosting                 0.495      0.248        0.504
# 2           AdaBoost                 0.484      0.243        0.503
# 3            XGBoost                 0.617      0.246        0.375
# 4           CatBoost                 0.943      0.253        0.079
# 5                MLP                 0.630      0.199        0.371
#
#    Balanced Accuracy  PR-AUC
# 0              0.491   0.242
# 1              0.499   0.256
# 2              0.493   0.257
# 3              0.496   0.248
# 4              0.511   0.258
# 5              0.501   0.250

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import recall_score, precision_score, balanced_accuracy_score, confusion_matrix, auc, precision_recall_curve
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from imblearn.pipeline import Pipeline
import pandas as pd
import numpy as np

# List untuk menyimpan hasil
cv_results = []

# Stratified K-Fold
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# Strategi
strategies = ["Cost-Sensitive", "SMOTE", "RUS"]

for name, model in models_weighted.items():
    for strategy in strategies:
        recalls, precisions, specs, bal_accs, pr_aucs = [], [], [], [], []

        for train_index, test_index in skf.split(X_train, y_train):
            X_tr, X_val = X_train.iloc[train_index], X_train.iloc[test_index]
            y_tr, y_val = y_train.iloc[train_index], y_train.iloc[test_index]

            # ==== Tentukan pipeline berdasarkan strategi ====
            if strategy == "SMOTE":
                pipeline = Pipeline([
                    ('smote', SMOTE(random_state=42)),
                    ('clf', model)
                ])
                pipeline.fit(X_tr, y_tr)
                y_pred = pipeline.predict(X_val)
                y_proba = pipeline.predict_proba(X_val)[:,1] if hasattr(pipeline.named_steps['clf'], "predict_proba") else y_pred

            elif strategy == "RUS":
                pipeline = Pipeline([
                    ('rus', RandomUnderSampler(random_state=42)),
                    ('clf', model)
                ])
                pipeline.fit(X_tr, y_tr)
                y_pred = pipeline.predict(X_val)
                y_proba = pipeline.predict_proba(X_val)[:,1] if hasattr(pipeline.named_steps['clf'], "predict_proba") else y_pred

            else:  # Cost-Sensitive
                if name in ["Gradient Boosting", "AdaBoost"]:
                    sample_weight = y_tr.map(class_weight_dict)
                    model.fit(X_tr, y_tr, sample_weight=sample_weight)
                else:
                    model.fit(X_tr, y_tr)
                y_pred = model.predict(X_val)
                y_proba = model.predict_proba(X_val)[:,1] if hasattr(model, "predict_proba") else y_pred

            # ==== Confusion matrix ====
            tn, fp, fn, tp = confusion_matrix(y_val, y_pred).ravel()
            spec = tn / (tn + fp) if (tn + fp) != 0 else 0

            # ==== Metrics ====
            recalls.append(recall_score(y_val, y_pred, zero_division=0))
            precisions.append(precision_score(y_val, y_pred, zero_division=0))
            specs.append(spec)
            bal_accs.append(balanced_accuracy_score(y_val, y_pred))
            precision_curve, recall_curve, _ = precision_recall_curve(y_val, y_proba)
            pr_aucs.append(auc(recall_curve, precision_curve))

        # Simpan rata-rata
        cv_results.append({
            "Model": name,
            "Strategy": strategy,
            "Sensitivity (Recall)": np.mean(recalls),
            "Precision": np.mean(precisions),
            "Specificity": np.mean(specs),
            "Balanced Accuracy": np.mean(bal_accs),
            "PR-AUC": np.mean(pr_aucs)
        })

# Gabungkan ke DataFrame
comparison_df = pd.DataFrame(cv_results)
pd.set_option('display.float_format', '{:.3f}'.format)
print(comparison_df.sort_values(["Model", "Strategy"]))
# Out:
#                 Model        Strategy  Sensitivity (Recall)  Precision  \
# 6            AdaBoost  Cost-Sensitive                 0.454      0.244
# 8            AdaBoost             RUS                 0.484      0.243
# 7            AdaBoost           SMOTE                 0.258      0.254
# 12           CatBoost  Cost-Sensitive                 0.169      0.261
# 14           CatBoost             RUS                 0.943      0.253
# 13           CatBoost           SMOTE                 0.387      0.255
# 3   Gradient Boosting  Cost-Sensitive                 0.342      0.238
# 5   Gradient Boosting             RUS                 0.495      0.248
# 4   Gradient Boosting           SMOTE                 0.102      0.264
# 15                MLP  Cost-Sensitive                 0.276      0.272
# 17                MLP             RUS                 0.630      0.199
# 16                MLP           SMOTE                 0.589      0.251
# ...

# %% [markdown]
# K-Fold membuat evaluasi lebih realistis:
#
# Hasil tanpa K-Fold cenderung lebih optimis, karena hanya menggunakan satu train/test split.
#
# K-Fold menghitung rata-rata di beberapa subset → lebih stabil, lebih representatif.
#
# Cost-Sensitive vs RUS vs SMOTE:
#
# RUS → recall sangat tinggi tapi spesifisitas rendah → trade-off antara mendeteksi non-adherence vs false positives.
#
# SMOTE → recall menurun tapi precision sedikit lebih tinggi → oversampling minoritas tidak selalu meningkatkan deteksi secara keseluruhan.
#
# Cost-Sensitive → performa lebih seimbang, cocok untuk dataset imbalanced tanpa menambahkan atau menghapus sampel.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")
plt.figure(figsize=(16,7))

# ---- Subplot 1: Recall vs Precision ----
plt.subplot(1,2,1)
sns.scatterplot(
    data=comparison_df,
    x="Precision",
    y="Sensitivity (Recall)",
    hue="Strategy",
    style="Model",
    s=150
)
plt.title("Recall vs Precision (Stratified K-Fold CV)")
plt.xlabel("Precision")
plt.ylabel("Sensitivity (Recall)")
plt.legend(bbox_to_anchor=(1.05, 1), loc=2)

# ---- Subplot 2: Balanced Accuracy vs PR-AUC ----
plt.subplot(1,2,2)
sns.scatterplot(
    data=comparison_df,
    x="Balanced Accuracy",
    y="PR-AUC",
    hue="Strategy",
    style="Model",
    s=150
)
plt.title("Balanced Accuracy vs PR-AUC (Stratified K-Fold CV)")
plt.xlabel("Balanced Accuracy")
plt.ylabel("PR-AUC")
plt.legend(bbox_to_anchor=(1.05, 1), loc=2)

plt.tight_layout()
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler

# Salin DataFrame agar aman
df_rank = comparison_df.copy()

# Normalisasi metrik agar skala 0-1
scaler = MinMaxScaler()
df_rank[["Recall_norm", "BalancedAcc_norm", "PR_AUC_norm"]] = scaler.fit_transform(
    df_rank[["Sensitivity (Recall)", "Balanced Accuracy", "PR-AUC"]]
)

# Weighted score: Recall 40%, Balanced Accuracy 30%, PR-AUC 30%
df_rank["Weighted_Score"] = (
    df_rank["Recall_norm"] * 0.4 +
    df_rank["BalancedAcc_norm"] * 0.3 +
    df_rank["PR_AUC_norm"] * 0.3
)

# Urutkan dari terbaik ke terburuk
df_rank = df_rank.sort_values("Weighted_Score", ascending=False).reset_index(drop=True)

# Tampilkan top 10 model-strategi terbaik
print(df_rank[["Model", "Strategy", "Sensitivity (Recall)", "Balanced Accuracy", "PR-AUC", "Weighted_Score"]])
# Out:
#                 Model        Strategy  Sensitivity (Recall)  \
# 0            CatBoost             RUS                 0.943
# 1             XGBoost           SMOTE                 0.238
# 2            CatBoost           SMOTE                 0.387
# 3                 MLP           SMOTE                 0.589
# 4            CatBoost  Cost-Sensitive                 0.169
# 5                 MLP             RUS                 0.630
# 6   Gradient Boosting             RUS                 0.495
# 7            AdaBoost             RUS                 0.484
# 8             XGBoost             RUS                 0.617
# 9       Random Forest  Cost-Sensitive                 0.002
# 10  Gradient Boosting           SMOTE                 0.102
# 11           AdaBoost           SMOTE                 0.258
# 12            XGBoost  Cost-Sensitive                 0.149
# 13      Random Forest           SMOTE                 0.077
# 14           AdaBoost  Cost-Sensitive                 0.454
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Pivot table Weighted Score
pivot_weighted = df_rank.pivot(index="Model", columns="Strategy", values="Weighted_Score")

plt.figure(figsize=(10,6))
sns.heatmap(
    pivot_weighted,
    annot=True,
    fmt=".3f",
    cmap="YlGnBu",
    cbar_kws={'label': 'Weighted Score'}
)
plt.title("Weighted Score per Model & Strategy (Recall 40%, Balanced Acc 30%, PR-AUC 30%)")
plt.xlabel("Strategy")
plt.ylabel("Model")
plt.tight_layout()
plt.show()
